# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# # 1. Problem Statement

# %% [raw]
# By using Linear Regression Model, We are trying to predict the Prices...For that we are using multiple input variable.

# %% [markdown]
# # 2. Data Gathering

# %%
df = pd.read_csv('autos.csv')
df
# Out:
#      symbol   loss         make    fuel  aspir doors        style drive  \
# 0         3    NaN  alfa-romero     gas    std   two  convertible   rwd
# 1         3    NaN  alfa-romero     gas    std   two  convertible   rwd
# 2         1    NaN  alfa-romero     gas    std   two    hatchback   rwd
# 3         2  164.0         audi     gas    std  four        sedan   fwd
# 4         2  164.0         audi     gas    std  four        sedan   4wd
# ..      ...    ...          ...     ...    ...   ...          ...   ...
# 200      -1   95.0        volvo     gas    std  four        sedan   rwd
# 201      -1   95.0        volvo     gas  turbo  four        sedan   rwd
# 202      -1   95.0        volvo     gas    std  four        sedan   rwd
# 203      -1   95.0        volvo  diesel  turbo  four        sedan   rwd
# 204      -1   95.0        volvo     gas  turbo  four        sedan   rwd
#
#     eng_loc     wb  ...  eng_cc  fuel.sys  bore  stroke comp.ratio     hp  \
# 0     front   88.6  ...     130      mpfi  3.47    2.68        9.0  111.0
# 1     front   88.6  ...     130      mpfi  3.47    2.68        9.0  111.0
# 2     front   94.5  ...     152      mpfi  2.68    3.47        9.0  154.0
# 3     front   99.8  ...     109      mpfi  3.19    3.40       10.0  102.0
# 4     front   99.4  ...     136      mpfi  3.19    3.40        8.0  115.0
# ..      ...    ...  ...     ...       ...   ...     ...        ...    ...
# 200   front  109.1  ...     141      mpfi  3.78    3.15        9.5  114.0
# 201   front  109.1  ...     141      mpfi  3.78    3.15        8.7  160.0
# 202   front  109.1  ...     173      mpfi  3.58    2.87        8.8  134.0
# 203   front  109.1  ...     145       idi  3.01    3.40       23.0  106.0
# 204   front  109.1  ...     141      mpfi  3.78    3.15        9.5  114.0
#
#         rpm city_mpg  hw_mpg    price
# 0    5000.0       21      27  13495.0
# 1    5000.0       21      27  16500.0
# 2    5000.0       19      26  16500.0
# 3    5500.0       24      30  13950.0
# 4    5500.0       18      22  17450.0
# ..      ...      ...     ...      ...
# 200  5400.0       23      28  16845.0
# 201  5300.0       19      25  19045.0
# 202  5500.0       18      23  21485.0
# 203  4800.0       26      27  22470.0
# 204  5400.0       19      25  22625.0
#
# [205 rows x 26 columns]

# %%
df.T
# Out:
#                     0            1            2        3        4        5    \
# symbol                3            3            1        2        2        2
# loss                NaN          NaN          NaN    164.0    164.0      NaN
# make        alfa-romero  alfa-romero  alfa-romero     audi     audi     audi
# fuel                gas          gas          gas      gas      gas      gas
# aspir               std          std          std      std      std      std
# doors               two          two          two     four     four      two
# style       convertible  convertible    hatchback    sedan    sedan    sedan
# drive               rwd          rwd          rwd      fwd      4wd      fwd
# eng_loc           front        front        front    front    front    front
# wb                 88.6         88.6         94.5     99.8     99.4     99.8
# length            168.8        168.8        171.2    176.6    176.6    177.3
# width              64.1         64.1         65.5     66.2     66.4     66.3
# height             48.8         48.8         52.4     54.3     54.3     53.1
# weight             2548         2548         2823     2337     2824     2507
# eng_type           dohc         dohc         ohcv      ohc      ohc      ohc
# cylinders          four         four          six     four     five     five
# eng_cc              130          130          152      109      136      136
# fuel.sys           mpfi         mpfi         mpfi     mpfi     mpfi     mpfi
# bore               3.47         3.47         2.68     3.19     3.19     3.19
# stroke             2.68         2.68         3.47      3.4      3.4      3.4
# comp.ratio          9.0          9.0          9.0     10.0      8.0      8.5
# hp                111.0        111.0        154.0    102.0    115.0    110.0
# rpm              5000.0       5000.0       5000.0   5500.0   5500.0   5500.0
# city_mpg             21           21           19       24       18       19
# hw_mpg               27           27           26       30       22       25
# price           13495.0      16500.0      16500.0  13950.0  17450.0  15250.0
#
#                 6        7        8          9    ...      195      196  \
# symbol            1        1        1          0  ...       -1       -2
# loss          158.0      NaN    158.0        NaN  ...     74.0    103.0
# make           audi     audi     audi       audi  ...    volvo    volvo
# fuel            gas      gas      gas        gas  ...      gas      gas
# aspir           std      std    turbo      turbo  ...      std      std
# doors          four     four     four        two  ...     four     four
# style         sedan    wagon    sedan  hatchback  ...    wagon    sedan
# drive           fwd      fwd      fwd        4wd  ...      rwd      rwd
# eng_loc       front    front    front      front  ...    front    front
# wb            105.8    105.8    105.8       99.5  ...    104.3    104.3
# length        192.7    192.7    192.7      178.2  ...    188.8    188.8
# width          71.4     71.4     71.4       67.9  ...     67.2     67.2
# height         55.7     55.7     55.9       52.0  ...     57.5     56.2
# weight         2844     2954     3086       3053  ...     3034     2935
# eng_type        ohc      ohc      ohc        ohc  ...      ohc      ohc
# cylinders      five     five     five       five  ...     four     four
# eng_cc          136      136      131        131  ...      141      141
# fuel.sys       mpfi     mpfi     mpfi       mpfi  ...     mpfi     mpfi
# bore           3.19     3.19     3.13       3.13  ...     3.78     3.78
# stroke          3.4      3.4      3.4        3.4  ...     3.15     3.15
# comp.ratio      8.5      8.5      8.3        7.0  ...      9.5      9.5
# hp            110.0    110.0    140.0      160.0  ...    114.0    114.0
# rpm          5500.0   5500.0   5500.0     5500.0  ...   5400.0   5400.0
# city_mpg         19       19       17         16  ...       23       24
# hw_mpg           25       25       20         22  ...       28       28
# price       17710.0  18920.0  23875.0        NaN  ...  13415.0  15985.0
#
#                 197      198      199      200      201      202      203  \
# symbol           -1       -2       -1       -1       -1       -1       -1
# loss           74.0    103.0     74.0     95.0     95.0     95.0     95.0
# make          volvo    volvo    volvo    volvo    volvo    volvo    volvo
# fuel            gas      gas      gas      gas      gas      gas   diesel
# aspir           std    turbo    turbo      std    turbo      std    turbo
# doors          four     four     four     four     four     four     four
# style         wagon    sedan    wagon    sedan    sedan    sedan    sedan
# drive           rwd      rwd      rwd      rwd      rwd      rwd      rwd
# eng_loc       front    front    front    front    front    front    front
# wb            104.3    104.3    104.3    109.1    109.1    109.1    109.1
# length        188.8    188.8    188.8    188.8    188.8    188.8    188.8
# width          67.2     67.2     67.2     68.9     68.8     68.9     68.9
# height         57.5     56.2     57.5     55.5     55.5     55.5     55.5
# weight         3042     3045     3157     2952     3049     3012     3217
# eng_type        ohc      ohc      ohc      ohc      ohc     ohcv      ohc
# cylinders      four     four     four     four     four      six      six
# eng_cc          141      130      130      141      141      173      145
# fuel.sys       mpfi     mpfi     mpfi     mpfi     mpfi     mpfi      idi
# bore           3.78     3.62     3.62     3.78     3.78     3.58     3.01
# stroke         3.15     3.15     3.15     3.15     3.15     2.87      3.4
# comp.ratio      9.5      7.5      7.5      9.5      8.7      8.8     23.0
# hp            114.0    162.0    162.0    114.0    160.0    134.0    106.0
# rpm          5400.0   5100.0   5100.0   5400.0   5300.0   5500.0   4800.0
# city_mpg         24       17       17       23       19       18       26
# hw_mpg           28       22       22       28       25       23       27
# price       16515.0  18420.0  18950.0  16845.0  19045.0  21485.0  22470.0
#
#                 204
# symbol           -1
# loss           95.0
# make          volvo
# fuel            gas
# aspir         turbo
# doors          four
# style         sedan
# drive           rwd
# eng_loc       front
# wb            109.1
# length        188.8
# width          68.9
# height         55.5
# weight         3062
# eng_type        ohc
# cylinders      four
# eng_cc          141
# fuel.sys       mpfi
# bore           3.78
# stroke         3.15
# comp.ratio      9.5
# hp            114.0
# rpm          5400.0
# city_mpg         19
# hw_mpg           25
# price       22625.0
#
# [26 rows x 205 columns]

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      205 non-null    int64
#  1   loss        164 non-null    float64
#  2   make        205 non-null    object
#  3   fuel        205 non-null    object
#  4   aspir       205 non-null    object
#  5   doors       203 non-null    object
#  6   style       205 non-null    object
#  7   drive       205 non-null    object
#  8   eng_loc     205 non-null    object
#  9   wb          205 non-null    float64
#  10  length      205 non-null    float64
#  11  width       205 non-null    float64
#  12  height      205 non-null    float64
#  13  weight      205 non-null    int64
#  14  eng_type    205 non-null    object
#  15  cylinders   205 non-null    object
#  16  eng_cc      205 non-null    int64
#  17  fuel.sys    205 non-null    object
#  18  bore        201 non-null    float64
#  19  stroke      201 non-null    float64
#  20  comp.ratio  205 non-null    float64
#  21  hp          203 non-null    float64
#  22  rpm         203 non-null    float64
#  23  city_mpg    205 non-null    int64
#  24  hw_mpg      205 non-null    int64
#  25  price       201 non-null    float64
# dtypes: float64(11), int64(5), object(10)
# memory usage: 41.8+ KB

# %%
df['cylinders'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylinders, dtype: int64

# %%
df['cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %% [markdown]
# # Encoding

# %% [raw]
# 1. Label Encoding
# 2. OneHot Encoding
# 3. Hash Encoding
# 4. Binary Encoding

# %% [markdown]
# # 1.Label Encoding

# %%
List1 = ['four', 'six', 'five', 'three', 'twelve', 'two', 'eight']
np.sort(List1)
# Out:
# array(['eight', 'five', 'four', 'six', 'three', 'twelve', 'two'],
#       dtype='<U6')

# %%
List1 = ['four', 'six', 'five', 'three', 'twelve', 'two', 'eight']
sorted(List1)
# Out:
# ['eight', 'five', 'four', 'six', 'three', 'twelve', 'two']

# %% [raw]
# ['eight', 'five', 'four', 'six', 'three', 'twelve', 'two']
#    0        1       2       3       4        5         6

# %% [raw]
# High
# Medium
# LOw
#
# High >> 0
# Low  >> 1
# Medium >> 2

# %%
Test = ['Low','Medium','Medium','High','High','Low']
sorted(Test)
# Out:
# ['High', 'High', 'Low', 'Low', 'Medium', 'Medium']

# %% [raw]
# Test = ['Low','Medium','Medium','High','High','Low']    >> Label Encoder original Output
#           1      2        2        0      0     1
#
#
#
# ['High', 'High', 'Low', 'Low', 'Medium', 'Medium']
#    0       0       1      1       2         2

# %%
df_test = pd.DataFrame({'Test':['Low','Medium','Medium','High','High','Low']})

# %%
labelEnc = LabelEncoder()
labelEnc.fit_transform(df_test['Test'])
# Out:
# array([1, 2, 2, 0, 0, 1])

# %%
df['cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df['cylinders'].replace({'four':4,'six':6,'five':5,'three':3,'twelve':12,'two':2,'eight':8},
                        inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      205 non-null    int64
#  1   loss        164 non-null    float64
#  2   make        205 non-null    object
#  3   fuel        205 non-null    object
#  4   aspir       205 non-null    object
#  5   doors       203 non-null    object
#  6   style       205 non-null    object
#  7   drive       205 non-null    object
#  8   eng_loc     205 non-null    object
#  9   wb          205 non-null    float64
#  10  length      205 non-null    float64
#  11  width       205 non-null    float64
#  12  height      205 non-null    float64
#  13  weight      205 non-null    int64
#  14  eng_type    205 non-null    object
#  15  cylinders   205 non-null    int64
#  16  eng_cc      205 non-null    int64
#  17  fuel.sys    205 non-null    object
#  18  bore        201 non-null    float64
#  19  stroke      201 non-null    float64
#  20  comp.ratio  205 non-null    float64
#  21  hp          203 non-null    float64
#  22  rpm         203 non-null    float64
#  23  city_mpg    205 non-null    int64
#  24  hw_mpg      205 non-null    int64
#  25  price       201 non-null    float64
# dtypes: float64(11), int64(6), object(9)
# memory usage: 41.8+ KB

# %%
labelEnc = LabelEncoder()
labelEnc.fit_transform(df['cylinders'])
# Out:
# array([2, 2, 4, 2, 3, 3, 3, 3, 3, 3, 2, 2, 4, 4, 4, 4, 4, 4, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 4, 4, 6, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 3, 3, 3, 3, 5, 5, 5, 5, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 4, 4, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 5, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 4, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 4, 4, 2], dtype=int64)

# %% [markdown]
# # OneHot Encoding

# %% [raw]
# Low
# Medium
# High
#
#
#            Low         Medium     High
#
#
# Low         1           0         0
# Medium      0           1         0
# Low         1           0         0
# High        0           0         1
# Low         1           0         0
# LOw         1           0         0
# Medium      0           1         0
# High        0           0         1

# %%
Test = ['Low','Medium','Medium','High','High','Low']

# %%
df_test = pd.DataFrame({'Test':['Low','Medium','Medium','High','High','Low']})

df_new = pd.get_dummies(df_test, columns = ['Test'])
df_new
# Out:
#    Test_High  Test_Low  Test_Medium
# 0          0         1            0
# 1          0         0            1
# 2          0         0            1
# 3          1         0            0
# 4          1         0            0
# 5          0         1            0

# %%
df_test = pd.DataFrame({'Test':['Low','Medium','Medium','High','High','Low']})

df_new = pd.get_dummies(df_test, columns = ['Test'], drop_first=True, prefix = 'test')
df_new
# Out:
#    test_Low  test_Medium
# 0         1            0
# 1         0            1
# 2         0            1
# 3         0            0
# 4         0            0
# 5         1            0

# %%
df_test
# Out:
#      Test
# 0     Low
# 1  Medium
# 2  Medium
# 3    High
# 4    High
# 5     Low

# %%
df_new
# Out:
#    test_Low  test_Medium
# 0         1            0
# 1         0            1
# 2         0            1
# 3         0            0
# 4         0            0
# 5         1            0

# %%
df.T
# Out:
#                     0            1            2        3        4        5    \
# symbol                3            3            1        2        2        2
# loss                NaN          NaN          NaN    164.0    164.0      NaN
# make        alfa-romero  alfa-romero  alfa-romero     audi     audi     audi
# fuel                gas          gas          gas      gas      gas      gas
# aspir               std          std          std      std      std      std
# doors               two          two          two     four     four      two
# style       convertible  convertible    hatchback    sedan    sedan    sedan
# drive               rwd          rwd          rwd      fwd      4wd      fwd
# eng_loc           front        front        front    front    front    front
# wb                 88.6         88.6         94.5     99.8     99.4     99.8
# length            168.8        168.8        171.2    176.6    176.6    177.3
# width              64.1         64.1         65.5     66.2     66.4     66.3
# height             48.8         48.8         52.4     54.3     54.3     53.1
# weight             2548         2548         2823     2337     2824     2507
# eng_type           dohc         dohc         ohcv      ohc      ohc      ohc
# cylinders             4            4            6        4        5        5
# eng_cc              130          130          152      109      136      136
# fuel.sys           mpfi         mpfi         mpfi     mpfi     mpfi     mpfi
# bore               3.47         3.47         2.68     3.19     3.19     3.19
# stroke             2.68         2.68         3.47      3.4      3.4      3.4
# comp.ratio          9.0          9.0          9.0     10.0      8.0      8.5
# hp                111.0        111.0        154.0    102.0    115.0    110.0
# rpm              5000.0       5000.0       5000.0   5500.0   5500.0   5500.0
# city_mpg             21           21           19       24       18       19
# hw_mpg               27           27           26       30       22       25
# price           13495.0      16500.0      16500.0  13950.0  17450.0  15250.0
#
#                 6        7        8          9    ...      195      196  \
# symbol            1        1        1          0  ...       -1       -2
# loss          158.0      NaN    158.0        NaN  ...     74.0    103.0
# make           audi     audi     audi       audi  ...    volvo    volvo
# fuel            gas      gas      gas        gas  ...      gas      gas
# aspir           std      std    turbo      turbo  ...      std      std
# doors          four     four     four        two  ...     four     four
# style         sedan    wagon    sedan  hatchback  ...    wagon    sedan
# drive           fwd      fwd      fwd        4wd  ...      rwd      rwd
# eng_loc       front    front    front      front  ...    front    front
# wb            105.8    105.8    105.8       99.5  ...    104.3    104.3
# length        192.7    192.7    192.7      178.2  ...    188.8    188.8
# width          71.4     71.4     71.4       67.9  ...     67.2     67.2
# height         55.7     55.7     55.9       52.0  ...     57.5     56.2
# weight         2844     2954     3086       3053  ...     3034     2935
# eng_type        ohc      ohc      ohc        ohc  ...      ohc      ohc
# cylinders         5        5        5          5  ...        4        4
# eng_cc          136      136      131        131  ...      141      141
# fuel.sys       mpfi     mpfi     mpfi       mpfi  ...     mpfi     mpfi
# bore           3.19     3.19     3.13       3.13  ...     3.78     3.78
# stroke          3.4      3.4      3.4        3.4  ...     3.15     3.15
# comp.ratio      8.5      8.5      8.3        7.0  ...      9.5      9.5
# hp            110.0    110.0    140.0      160.0  ...    114.0    114.0
# rpm          5500.0   5500.0   5500.0     5500.0  ...   5400.0   5400.0
# city_mpg         19       19       17         16  ...       23       24
# hw_mpg           25       25       20         22  ...       28       28
# price       17710.0  18920.0  23875.0        NaN  ...  13415.0  15985.0
#
#                 197      198      199      200      201      202      203  \
# symbol           -1       -2       -1       -1       -1       -1       -1
# loss           74.0    103.0     74.0     95.0     95.0     95.0     95.0
# make          volvo    volvo    volvo    volvo    volvo    volvo    volvo
# fuel            gas      gas      gas      gas      gas      gas   diesel
# aspir           std    turbo    turbo      std    turbo      std    turbo
# doors          four     four     four     four     four     four     four
# style         wagon    sedan    wagon    sedan    sedan    sedan    sedan
# drive           rwd      rwd      rwd      rwd      rwd      rwd      rwd
# eng_loc       front    front    front    front    front    front    front
# wb            104.3    104.3    104.3    109.1    109.1    109.1    109.1
# length        188.8    188.8    188.8    188.8    188.8    188.8    188.8
# width          67.2     67.2     67.2     68.9     68.8     68.9     68.9
# height         57.5     56.2     57.5     55.5     55.5     55.5     55.5
# weight         3042     3045     3157     2952     3049     3012     3217
# eng_type        ohc      ohc      ohc      ohc      ohc     ohcv      ohc
# cylinders         4        4        4        4        4        6        6
# eng_cc          141      130      130      141      141      173      145
# fuel.sys       mpfi     mpfi     mpfi     mpfi     mpfi     mpfi      idi
# bore           3.78     3.62     3.62     3.78     3.78     3.58     3.01
# stroke         3.15     3.15     3.15     3.15     3.15     2.87      3.4
# comp.ratio      9.5      7.5      7.5      9.5      8.7      8.8     23.0
# hp            114.0    162.0    162.0    114.0    160.0    134.0    106.0
# rpm          5400.0   5100.0   5100.0   5400.0   5300.0   5500.0   4800.0
# city_mpg         24       17       17       23       19       18       26
# hw_mpg           28       22       22       28       25       23       27
# price       16515.0  18420.0  18950.0  16845.0  19045.0  21485.0  22470.0
#
#                 204
# symbol           -1
# loss           95.0
# make          volvo
# fuel            gas
# aspir         turbo
# doors          four
# style         sedan
# drive           rwd
# eng_loc       front
# wb            109.1
# length        188.8
# width          68.9
# height         55.5
# weight         3062
# eng_type        ohc
# cylinders         4
# eng_cc          141
# fuel.sys       mpfi
# bore           3.78
# stroke         3.15
# comp.ratio      9.5
# hp            114.0
# rpm          5400.0
# city_mpg         19
# hw_mpg           25
# price       22625.0
#
# [26 rows x 205 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      205 non-null    int64
#  1   loss        164 non-null    float64
#  2   make        205 non-null    object
#  3   fuel        205 non-null    object
#  4   aspir       205 non-null    object
#  5   doors       203 non-null    object
#  6   style       205 non-null    object
#  7   drive       205 non-null    object
#  8   eng_loc     205 non-null    object
#  9   wb          205 non-null    float64
#  10  length      205 non-null    float64
#  11  width       205 non-null    float64
#  12  height      205 non-null    float64
#  13  weight      205 non-null    int64
#  14  eng_type    205 non-null    object
#  15  cylinders   205 non-null    int64
#  16  eng_cc      205 non-null    int64
#  17  fuel.sys    205 non-null    object
#  18  bore        201 non-null    float64
#  19  stroke      201 non-null    float64
#  20  comp.ratio  205 non-null    float64
#  21  hp          203 non-null    float64
#  22  rpm         203 non-null    float64
#  23  city_mpg    205 non-null    int64
#  24  hw_mpg      205 non-null    int64
#  25  price       201 non-null    float64
# dtypes: float64(11), int64(6), object(9)
# memory usage: 41.8+ KB

# %%
df.head().T
# Out:
#                       0            1            2        3        4
# symbol                3            3            1        2        2
# loss                NaN          NaN          NaN    164.0    164.0
# make        alfa-romero  alfa-romero  alfa-romero     audi     audi
# fuel                gas          gas          gas      gas      gas
# aspir               std          std          std      std      std
# doors               two          two          two     four     four
# style       convertible  convertible    hatchback    sedan    sedan
# drive               rwd          rwd          rwd      fwd      4wd
# eng_loc           front        front        front    front    front
# wb                 88.6         88.6         94.5     99.8     99.4
# length            168.8        168.8        171.2    176.6    176.6
# width              64.1         64.1         65.5     66.2     66.4
# height             48.8         48.8         52.4     54.3     54.3
# weight             2548         2548         2823     2337     2824
# eng_type           dohc         dohc         ohcv      ohc      ohc
# cylinders             4            4            6        4        5
# eng_cc              130          130          152      109      136
# fuel.sys           mpfi         mpfi         mpfi     mpfi     mpfi
# bore               3.47         3.47         2.68     3.19     3.19
# stroke             2.68         2.68         3.47      3.4      3.4
# comp.ratio          9.0          9.0          9.0     10.0      8.0
# hp                111.0        111.0        154.0    102.0    115.0
# rpm              5000.0       5000.0       5000.0   5500.0   5500.0
# city_mpg             21           21           19       24       18
# hw_mpg               27           27           26       30       22
# price           13495.0      16500.0      16500.0  13950.0  17450.0

# %%
df.drop(['make','fuel','aspir','doors','style','drive','eng_loc','eng_type','fuel.sys'
        ],axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      205 non-null    int64
#  1   loss        164 non-null    float64
#  2   wb          205 non-null    float64
#  3   length      205 non-null    float64
#  4   width       205 non-null    float64
#  5   height      205 non-null    float64
#  6   weight      205 non-null    int64
#  7   cylinders   205 non-null    int64
#  8   eng_cc      205 non-null    int64
#  9   bore        201 non-null    float64
#  10  stroke      201 non-null    float64
#  11  comp.ratio  205 non-null    float64
#  12  hp          203 non-null    float64
#  13  rpm         203 non-null    float64
#  14  city_mpg    205 non-null    int64
#  15  hw_mpg      205 non-null    int64
#  16  price       201 non-null    float64
# dtypes: float64(11), int64(6)
# memory usage: 27.4 KB

# %%
df.isna().sum()
# Out:
# symbol         0
# loss          41
# wb             0
# length         0
# width          0
# height         0
# weight         0
# cylinders      0
# eng_cc         0
# bore           4
# stroke         4
# comp.ratio     0
# hp             2
# rpm            2
# city_mpg       0
# hw_mpg         0
# price          4
# dtype: int64

# %%
df.drop(['loss'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      205 non-null    int64
#  1   wb          205 non-null    float64
#  2   length      205 non-null    float64
#  3   width       205 non-null    float64
#  4   height      205 non-null    float64
#  5   weight      205 non-null    int64
#  6   cylinders   205 non-null    int64
#  7   eng_cc      205 non-null    int64
#  8   bore        201 non-null    float64
#  9   stroke      201 non-null    float64
#  10  comp.ratio  205 non-null    float64
#  11  hp          203 non-null    float64
#  12  rpm         203 non-null    float64
#  13  city_mpg    205 non-null    int64
#  14  hw_mpg      205 non-null    int64
#  15  price       201 non-null    float64
# dtypes: float64(10), int64(6)
# memory usage: 25.8 KB

# %%
df.isna().sum()
# Out:
# symbol        0
# wb            0
# length        0
# width         0
# height        0
# weight        0
# cylinders     0
# eng_cc        0
# bore          4
# stroke        4
# comp.ratio    0
# hp            2
# rpm           2
# city_mpg      0
# hw_mpg        0
# price         4
# dtype: int64

# %%
df.corr()
# Out:
#               symbol        wb    length     width    height    weight  \
# symbol      1.000000 -0.531954 -0.357612 -0.232919 -0.541038 -0.227691
# wb         -0.531954  1.000000  0.874587  0.795144  0.589435  0.776386
# length     -0.357612  0.874587  1.000000  0.841118  0.491029  0.877728
# width      -0.232919  0.795144  0.841118  1.000000  0.279210  0.867032
# height     -0.541038  0.589435  0.491029  0.279210  1.000000  0.295572
# weight     -0.227691  0.776386  0.877728  0.867032  0.295572  1.000000
# cylinders  -0.113129  0.339507  0.430672  0.545007 -0.013995  0.609727
# eng_cc     -0.105790  0.569329  0.683360  0.735433  0.067149  0.850594
# bore       -0.134205  0.490378  0.607480  0.559204  0.176195  0.649045
# stroke     -0.008965  0.161477  0.129739  0.182956 -0.056999  0.168929
# comp.ratio -0.178515  0.249786  0.158414  0.181129  0.261214  0.151362
# hp          0.071622  0.352297  0.555003  0.642482 -0.110711  0.751034
# rpm         0.274573 -0.361052 -0.287325 -0.219957 -0.322272 -0.266306
# city_mpg   -0.035823 -0.470414 -0.670909 -0.642704 -0.048640 -0.757414
# hw_mpg      0.034606 -0.544082 -0.704662 -0.677218 -0.107358 -0.797465
# price      -0.082391  0.584642  0.690628  0.751265  0.135486  0.834415
#
#             cylinders    eng_cc      bore    stroke  comp.ratio        hp  \
# symbol      -0.113129 -0.105790 -0.134205 -0.008965   -0.178515  0.071622
# wb           0.339507  0.569329  0.490378  0.161477    0.249786  0.352297
# length       0.430672  0.683360  0.607480  0.129739    0.158414  0.555003
# width        0.545007  0.735433  0.559204  0.182956    0.181129  0.642482
# height      -0.013995  0.067149  0.176195 -0.056999    0.261214 -0.110711
# weight       0.609727  0.850594  0.649045  0.168929    0.151362  0.751034
# cylinders    1.000000  0.846031  0.243553  0.008578   -0.020002  0.691633
# eng_cc       0.846031  1.000000  0.594090  0.206675    0.028971  0.810773
# bore         0.243553  0.594090  1.000000 -0.055909    0.005203  0.577273
# stroke       0.008578  0.206675 -0.055909  1.000000    0.186170  0.090254
# comp.ratio  -0.020002  0.028971  0.005203  0.186170    1.000000 -0.205874
# hp           0.691633  0.810773  0.577273  0.090254   -0.205874  1.000000
# rpm         -0.124434 -0.244618 -0.264269 -0.071493   -0.436221  0.130971
# city_mpg    -0.445837 -0.653658 -0.594584 -0.042906    0.324701 -0.803620
# hw_mpg      -0.466666 -0.677470 -0.594572 -0.044528    0.265201 -0.770908
# price        0.708645  0.872335  0.543436  0.082310    0.071107  0.810533
#
#                  rpm  city_mpg    hw_mpg     price
# symbol      0.274573 -0.035823  0.034606 -0.082391
# wb         -0.361052 -0.470414 -0.544082  0.584642
# length     -0.287325 -0.670909 -0.704662  0.690628
# width      -0.219957 -0.642704 -0.677218  0.751265
# height     -0.322272 -0.048640 -0.107358  0.135486
# weight     -0.266306 -0.757414 -0.797465  0.834415
# cylinders  -0.124434 -0.445837 -0.466666  0.708645
# eng_cc     -0.244618 -0.653658 -0.677470  0.872335
# bore       -0.264269 -0.594584 -0.594572  0.543436
# stroke     -0.071493 -0.042906 -0.044528  0.082310
# comp.ratio -0.436221  0.324701  0.265201  0.071107
# hp          0.130971 -0.803620 -0.770908  0.810533
# rpm         1.000000 -0.113788 -0.054257 -0.101649
# city_mpg   -0.113788  1.000000  0.971337 -0.686571
# hw_mpg     -0.054257  0.971337  1.000000 -0.704692
# price      -0.101649 -0.686571 -0.704692  1.000000

# %%
plt.figure(figsize = (20,10))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['symbol','height','stroke','comp.ratio','rpm'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   wb         205 non-null    float64
#  1   length     205 non-null    float64
#  2   width      205 non-null    float64
#  3   weight     205 non-null    int64
#  4   cylinders  205 non-null    int64
#  5   eng_cc     205 non-null    int64
#  6   bore       201 non-null    float64
#  7   hp         203 non-null    float64
#  8   city_mpg   205 non-null    int64
#  9   hw_mpg     205 non-null    int64
#  10  price      201 non-null    float64
# dtypes: float64(6), int64(5)
# memory usage: 17.7 KB

# %%
df.isna().sum()
# Out:
# wb           0
# length       0
# width        0
# weight       0
# cylinders    0
# eng_cc       0
# bore         4
# hp           2
# city_mpg     0
# hw_mpg       0
# price        4
# dtype: int64

# %%
df['bore'] = df['bore'].fillna(df['bore'].median())
df['hp'] = df['hp'].fillna(df['hp'].median())
df['price'] = df['price'].fillna(df['price'].median())

# %%
df.isna().sum()
# Out:
# wb           0
# length       0
# width        0
# weight       0
# cylinders    0
# eng_cc       0
# bore         0
# hp           0
# city_mpg     0
# hw_mpg       0
# price        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   wb         205 non-null    float64
#  1   length     205 non-null    float64
#  2   width      205 non-null    float64
#  3   weight     205 non-null    int64
#  4   cylinders  205 non-null    int64
#  5   eng_cc     205 non-null    int64
#  6   bore       205 non-null    float64
#  7   hp         205 non-null    float64
#  8   city_mpg   205 non-null    int64
#  9   hw_mpg     205 non-null    int64
#  10  price      205 non-null    float64
# dtypes: float64(6), int64(5)
# memory usage: 17.7 KB

# %% [markdown]
# # Train Test And Split

# %%
x = df.drop(['price'], axis = 1)
y = df['price']

# %%
x
# Out:
#         wb  length  width  weight  cylinders  eng_cc  bore     hp  city_mpg  \
# 0     88.6   168.8   64.1    2548          4     130  3.47  111.0        21
# 1     88.6   168.8   64.1    2548          4     130  3.47  111.0        21
# 2     94.5   171.2   65.5    2823          6     152  2.68  154.0        19
# 3     99.8   176.6   66.2    2337          4     109  3.19  102.0        24
# 4     99.4   176.6   66.4    2824          5     136  3.19  115.0        18
# ..     ...     ...    ...     ...        ...     ...   ...    ...       ...
# 200  109.1   188.8   68.9    2952          4     141  3.78  114.0        23
# 201  109.1   188.8   68.8    3049          4     141  3.78  160.0        19
# 202  109.1   188.8   68.9    3012          6     173  3.58  134.0        18
# 203  109.1   188.8   68.9    3217          6     145  3.01  106.0        26
# 204  109.1   188.8   68.9    3062          4     141  3.78  114.0        19
#
#      hw_mpg
# 0        27
# 1        27
# 2        26
# 3        30
# 4        22
# ..      ...
# 200      28
# 201      25
# 202      23
# 203      27
# 204      25
#
# [205 rows x 10 columns]

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape
# Out:
# (164, 10)

# %%
y_train.shape
# Out:
# (164,)

# %%
x_test.shape
# Out:
# (41, 10)

# %% [markdown]
# # Model Training / Building

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluation

# %%
y_pred = linear_model.predict(x_test)
y_pred
# Out:
# array([ 6712.93734248,  6667.90670728,  6130.19108513,  5132.16175868,
#         9418.09314937, 24221.82343527,  6784.62860871,  -856.59142954,
#         6093.41390036, 12170.23910643, 15992.83557123, 16348.03977409,
#        15872.2336163 , 10459.52989627, 19239.17387115, 15912.5979065 ,
#        10259.16808776,  7576.70757353, 13500.19147042,  9697.64227996,
#        12257.86261909,  6687.15950821,  9542.2778796 ,  8934.92793851,
#        15724.29872051,  7600.24497177, 19442.81018791,  6578.61585105,
#         6113.88798511,  7460.61941301,  7457.57859649, 12262.79715051,
#        26402.32545941, 13843.42270225, 17822.4435052 ,  6574.20258888,
#         9027.60644412, 36313.05378367, 10445.92426312, 16949.01001014,
#         5342.31187649])

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44     10295.0
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
# 163     8058.0
# 28      8921.0
# 16     41315.0
# 130     9295.0
# 116    17950.0
# 182     7775.0
# 27      8558.0
# 47     32250.0
# 58     15645.0
# 204    22625.0
# 138     5118.0
# Name: price, dtype: float64

# %%
y_test - y_pred
# Out:
# 78       -43.937342
# 97      1331.093293
# 151      207.808915
# 44      5162.838241
# 40       876.906851
# 67      1330.176565
# 98      1464.371391
# 18      6007.591430
# 152      394.586100
# 62     -1925.239106
# 4       1457.164429
# 172     1320.960226
# 197      642.766384
# 38     -1364.529896
# 29     -6275.173871
# 170    -4713.597906
# 190     -279.168088
# 33     -1047.707574
# 136     4649.808530
# 145     1561.357720
# 173    -3309.862619
# 31       167.840492
# 11      7382.722120
# 119     -977.927939
# 169    -5735.298721
# 34      -471.244972
# 84     -4953.810188
# 184     1416.384149
# 120      115.112015
# 35      -165.619413
# 163      600.421404
# 28     -3341.797151
# 16     14912.674541
# 130    -4548.422702
# 116      127.556495
# 182     1200.797411
# 27      -469.606444
# 47     -4063.053784
# 58      5199.075737
# 204     5675.989990
# 138     -224.311876
# Name: price, dtype: float64

# %%
df_residual = pd.DataFrame()
df_residual['Residuals'] = y_test - y_pred

# %%
sns.kdeplot(df_residual['Residuals'], fill = True)
# Out:
# <AxesSubplot:xlabel='Residuals', ylabel='Density'>

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 15227248.220914861

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 3902.210683819476

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 2612.59302481687

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7220214597301231

# %%
M_Values = linear_model.coef_
M_Values
# Out:
# array([ 1.42917226e+01, -1.93344105e+01,  3.74368577e+02,  1.47108739e+00,
#        -1.50899387e+03,  1.59998989e+02, -3.44612668e+03,  1.03392796e+01,
#         3.89306748e+01, -1.78993724e+02])

# %% [raw]
# wb	length	width	weight	cylinders	eng_cc	bore	hp	city_mpg	hw_mpg

# %%
x.columns
# Out:
# Index(['wb', 'length', 'width', 'weight', 'cylinders', 'eng_cc', 'bore', 'hp',
#        'city_mpg', 'hw_mpg'],
#       dtype='object')

# %%
for i, feature_name in enumerate(x.columns):
    print(f'Slope of attributes or values for {feature_name} is {M_Values[i]}')
# Out:
# Slope of attributes or values for wb is 14.291722620771537
# Slope of attributes or values for length is -19.33441053661751
# Slope of attributes or values for width is 374.36857669382675
# Slope of attributes or values for weight is 1.471087390526854
# Slope of attributes or values for cylinders is -1508.9938723049418
# Slope of attributes or values for eng_cc is 159.9989889539514
# Slope of attributes or values for bore is -3446.1266847568136
# Slope of attributes or values for hp is 10.339279628410292
# Slope of attributes or values for city_mpg is 38.93067475013713
# Slope of attributes or values for hw_mpg is -178.993723608424

# %%
for i, feature_name in enumerate(x.columns):
    print(f'Slope of attributes or values for {feature_name} is {round(M_Values[i],4)}')
# Out:
# Slope of attributes or values for wb is 14.2917
# Slope of attributes or values for length is -19.3344
# Slope of attributes or values for width is 374.3686
# Slope of attributes or values for weight is 1.4711
# Slope of attributes or values for cylinders is -1508.9939
# Slope of attributes or values for eng_cc is 159.999
# Slope of attributes or values for bore is -3446.1267
# Slope of attributes or values for hp is 10.3393
# Slope of attributes or values for city_mpg is 38.9307
# Slope of attributes or values for hw_mpg is -178.9937

# %%
linear_model.intercept_
# Out:
# -12199.385435053477

# %%
# for x_train dataset

# %%
y_pred = linear_model.predict(x_train)
y_pred
# Out:
# array([21809.29455322,  6317.95889918,  9092.90633153,  9901.61853447,
#         6743.60520923, 41780.47430683,  6074.92697595, 16744.71566611,
#        20985.45856784, 24210.97599864, 14469.49998739, 18499.04889156,
#         7589.28647052, 12133.46192167,  5132.16175868, 12732.17225235,
#        10328.85436389, 19253.61286929,  7509.06665516,  8356.79905411,
#        12667.44440717, 19283.93274973, 18687.80480201,  7203.52405951,
#         5992.25094739,  6636.13180332,  8815.52819309, 22540.89562956,
#        12482.4382827 , 11158.85006284, 28059.39996909, 14931.49971821,
#         6026.01025404, 16130.53309784, 36313.05378367,  8638.92298993,
#        13188.19162951, 19334.52267577,  5827.30005011,  6648.7825712 ,
#         7530.05936685,  6544.92438511, 15964.08596517, 12228.33588366,
#        16910.30808121, 21626.95221913, 21791.75501333, 15714.82726551,
#         7349.81942671, 11321.3745772 , 11835.15188123, 10505.22019173,
#        15642.06158078, 16991.21788769, 19340.46032744, 20650.40779312,
#         9897.2052723 ,  5183.64981735, 17741.53369872,  7531.12329834,
#         8690.4110486 , 15514.167289  ,  9163.0276874 , 17822.4435052 ,
#         6449.56726656, 20192.50324452,  5738.40758065, 15965.7713101 ,
#        17147.77464456,  5676.62191025,  6587.58591944,  9994.29704007,
#        18223.51138687, 24974.88777063, 11901.182761  ,  8409.81571974,
#        17124.53632342, 15708.11675922, 13486.77627747,  5584.00479115,
#         6624.67209905, 14692.81763059, 15143.87314401,  8356.79905411,
#        16405.93192536, 11227.02494496, 10506.32791442, 12124.02784756,
#        41025.51767922,  6617.00766725,  9194.11040172, 11227.02494496,
#        17284.36735315,  9542.2778796 ,  4059.26585098, 19435.45475096,
#         7562.80689749, 11289.0106546 , 17473.15694662,  8934.92793851,
#        21626.95221913, 16655.94045419, 12667.44440717, 21747.16440415,
#         7540.92902602, 12629.54702176, 14529.73123461, 11256.11593613,
#        12192.30541729, 25900.09894471, 11498.96522198, 15702.23240965,
#        14632.58638337, 11166.87841475,  6082.2824129 ,  6146.2519077 ,
#         6283.02670457,  9289.06437932,  6113.88798511, 11063.50378076,
#        10723.74536259, 39817.7326799 , 10906.26195242, 13796.67188997,
#        15821.53424243,  4181.96977927,  5952.90780233, 14550.40979387,
#        20297.30361849, 18014.59778564, 12170.23910643, 21691.68006431,
#        13486.77627747,  8364.15449106,  5980.01903257, 12133.46192167,
#        10611.36890917, 17286.35593638, 17368.05587931,  7743.21022685,
#        11960.02625662,  6665.55355113, 24567.52897205,  7274.24149256,
#         8369.66135486,  7084.56294009,  7043.37249316,  8002.48853993,
#         8663.90385719, 21552.13623839,  5127.58002679, 20630.49497225,
#         6146.2519077 , 16000.6482496 , 30327.48613569, 23286.20677499,
#         9929.89214136,  8887.74180092,  8949.93221832, 12536.86851615,
#        13557.56387865, 29956.94866235,  8259.7766994 , 10381.56226457])

# %%
y_test
# Out:
# 78      6669.0
# 97      7999.0
# 151     6338.0
# 44     10295.0
# 40     10295.0
# 67     25552.0
# 98      8249.0
# 18      5151.0
# 152     6488.0
# 62     10245.0
# 4      17450.0
# 172    17669.0
# 197    16515.0
# 38      9095.0
# 29     12964.0
# 170    11199.0
# 190     9980.0
# 33      6529.0
# 136    18150.0
# 145    11259.0
# 173     8948.0
# 31      6855.0
# 11     16925.0
# 119     7957.0
# 169     9989.0
# 34      7129.0
# 84     14489.0
# 184     7995.0
# 120     6229.0
# 35      7295.0
# 163     8058.0
# 28      8921.0
# 16     41315.0
# 130     9295.0
# 116    17950.0
# 182     7775.0
# 27      8558.0
# 47     32250.0
# 58     15645.0
# 204    22625.0
# 138     5118.0
# Name: price, dtype: float64

# %%
x_test - x_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13168\1387365531.py in <module>
# ----> 1 x_test - x_pred
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __sub__(self, other)
#     106     @unpack_zerodim_and_defer("__sub__")
#     107     def __sub__(self, other):
# --> 108         return self._arith_method(other, operator.sub)
#     109
#     110     @unpack_zerodim_and_defer("__rsub__")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    6951         other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6952
# -> 6953         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6954
#    6955         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     246
#     247         if right.ndim == 1:
# --> 248             right = to_series(right)
#     249
#     250         elif right.ndim == 2:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in to_series(right)
#     237         else:
#     238             if len(left.columns) != len(right):
# --> 239                 raise ValueError(
#     240                     msg.format(req_len=len(left.columns), given_len=len(right))
#     241                 )
#
# ValueError: Unable to coerce to Series, length must be 10: given 164
